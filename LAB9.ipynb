# %% [markdown]
# # Name: Abhijeet Chandra
# # Registration Number: 240911212
# # Section: PC
# # Roll no: 23
# # Branch: Information Technology

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sentiment.csv')

# %%
# 1. In the sentiment feature and text, trim white spaces and convert to lowercase.
# 2. What are the sentiment categories? Tabulate and visualize the number of texts for each
# category.
# 3. Tabulate and Visualize the text length for each sentiment category.
# 4. Find and display the text(s) with the maximum number of likes.
# 5. Find and display the text(s) with the maximum reposts. what is its sentiment?
# 6. Tabulate and Visualize the top 5 countries that have posted the most texts with a
# positive sentiment.
# 7. Find and display all the text(s) with the word ‘Travel’ in their hashtag.
# 8. Find and display the most popular (most number of likes) posts (top 5) from the year
# 2020 which were of a negative sentiment.
# 9. Find and display a list of Users and their posts whose texts are labeled ‘Happiness’
# sentiment.
# 10. Tabulate and visualize the years and countrywide tweets of the sentiments. Pick tweets
# with sentiments, ‘Positive,’ ‘Negative,’ and ‘Neutral’ only.

# %%
df
# Out:
#       ID                                               Text    Sentiment  \
# 0      0   Enjoying a beautiful day at the park!        ...   Positive
# 1      1   Traffic was terrible this morning.           ...   Negative
# 2      2   Just finished an amazing workout! 💪          ...   Positive
# 3      3   Excited about the upcoming weekend getaway!  ...   Positive
# 4      4   Trying out a new recipe for dinner tonight.  ...   Neutral
# ..   ...                                                ...          ...
# 727  728  Collaborating on a science project that receiv...       Happy
# 728  729  Attending a surprise birthday party organized ...       Happy
# 729  730  Successfully fundraising for a school charity ...       Happy
# 730  731  Participating in a multicultural festival, cel...       Happy
# 731  732  Organizing a virtual talent show during challe...       Happy
#
#             Timestamp                                   User     Platform  \
# ...

# %%
# 1. In the sentiment feature and text, trim white spaces and convert to lowercase.
df['Text'] = df['Text'].str.strip().str.lower()
df['Sentiment'] = df['Sentiment'].str.strip().str.lower()
df['Country'] = df['Country'].str.strip()

# %%
print('New dataframe: ')
df
# Out:
# New dataframe:
#       ID                                               Text Sentiment  \
# 0      0              enjoying a beautiful day at the park!  positive
# 1      1                 traffic was terrible this morning.  negative
# 2      2                just finished an amazing workout! 💪  positive
# 3      3        excited about the upcoming weekend getaway!  positive
# 4      4        trying out a new recipe for dinner tonight.   neutral
# ..   ...                                                ...       ...
# 727  728  collaborating on a science project that receiv...     happy
# 728  729  attending a surprise birthday party organized ...     happy
# 729  730  successfully fundraising for a school charity ...     happy
# 730  731  participating in a multicultural festival, cel...     happy
# 731  732  organizing a virtual talent show during challe...     happy
#
#             Timestamp                                   User     Platform  \
# ...

# %%
# 2. What are the sentiment categories? Tabulate and visualize the number of texts for each category.
print(f"Sentiment categories: \n")
print(df['Sentiment'].unique())
texts = df.groupby('Sentiment')['Text'].count().sort_values(ascending = False).head(10)
print(texts)
plt.figure(figsize=(12,6))
sns.barplot(x = texts.index, y= texts.values, palette = 'viridis')
plt.title('Number of texts in each Category')
plt.xlabel('Categories', fontsize = 10)
plt.ylabel('Number of texts', fontsize = 10)
plt.xticks(fontsize=10)  
plt.yticks(fontsize=10)
plt.show()
# Out:
# Sentiment categories:
#
# ['positive' 'negative' 'neutral' 'anger' 'fear' 'sadness' 'disgust'
#  'happiness' 'joy' 'love' 'amusement' 'enjoyment' 'admiration' 'affection'
#  'awe' 'disappointed' 'surprise' 'acceptance' 'adoration' 'anticipation'
#  'bitter' 'calmness' 'confusion' 'excitement' 'kind' 'pride' 'shame'
#  'elation' 'euphoria' 'contentment' 'serenity' 'gratitude' 'hope'
#  'empowerment' 'compassion' 'tenderness' 'arousal' 'enthusiasm'
#  'fulfillment' 'reverence' 'despair' 'grief' 'loneliness' 'jealousy'
#  'resentment' 'frustration' 'boredom' 'anxiety' 'intimidation'
#  'helplessness' 'envy' 'regret' 'curiosity' 'indifference' 'numbness'
#  'melancholy' 'nostalgia' 'ambivalence' 'determination' 'zest' 'hopeful'
#  'proud' 'grateful' 'empathetic' 'compassionate' 'playful' 'free-spirited'
#  'inspired' 'confident' 'bitterness' 'yearning' 'fearful' 'apprehensive'
#  'overwhelmed' 'jealous' 'devastated' 'frustrated' 'envious' 'dismissive'
# ...

# %% [markdown]
# # Observation:
# 1. Most Frequent Categories:
#
# "Positive" and "Joy" have the highest number of texts, both around 45.
#
# "Excitement" follows closely with slightly fewer texts.
#
# 2. Moderate Categories:
#
# "Contentment," "Gratitude," and "Neutral" fall in the mid-range, each having roughly half the number of texts as the top categories.
#
# 2. Less Frequent Categories:
#
# "Curiosity," "Serenity," "Happy," and "Nostalgia" appear least frequently, with "Nostalgia" having the fewest entries.

# %%
# 3. Tabulate and Visualize the text length for each sentiment category.
df['Text_length'] = df['Text'].apply(len)
text_lengths = df.groupby('Sentiment')['Text_length'].mean().sort_values(ascending = False).head(10)
plt.figure(figsize = (12,6))
sns.barplot(x=text_lengths.index, y= text_lengths.values, palette = 'magma')
plt.xlabel('Category')
plt.ylabel('Mean text length for each category')
plt.xticks(rotation = 45)
plt.show()
# Out:
# C:\Users\ABHIJEET CHANDRA\AppData\Local\Temp\ipykernel_99152\1773492199.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=text_lengths.index, y= text_lengths.values, palette = 'magma')

# %% [markdown]
# The X-axis represents different text categories.
#
# The Y-axis represents mean text length for each category.
#
# The bar height shows the average length of text in each category.
#
# # Observations:
# 1. Winter magic has the highest mean text length.
#
# 2. Mesmerizing has the lowest mean text length.
#
# 3. Other categories fall in between in descending order.

# %%
# 4. Find and display the text(s) with the maximum number of likes.
likes = df.groupby('Text')['Likes'].sum().sort_values(ascending = False).head(10)
plt.figure(figsize = (18,16))
sns.barplot(y= likes.index, x = likes.values, palette = 'Blues')
plt.xticks(fontsize = 35)
plt.yticks(fontsize = 25)
plt.xlabel('Number of likes', fontsize = 30)
plt.ylabel('Texts with most number of likes', fontsize = 30)
plt.title('Texts with maximum number of likes', fontsize = 40)
plt.show()
# Out:
# C:\Users\ABHIJEET CHANDRA\AppData\Local\Temp\ipykernel_99152\769001176.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y= likes.index, x = likes.values, palette = 'Blues')

# %% [markdown]
# The Y-axis (vertical) represents different text entries (phrases or sentences).
#
# The X-axis (horizontal) represents the number of likes each text received.
#
# The bar length indicates the number of likes a particular text received.
#
# # Observations:
# 1. The topmost text ("a playful escapade...") received the highest number of likes, around 140.
#
# 2. The bottom-most text ("embraced by the hopeful dawn...") received the least number of likes among the top-ranked texts, around 80.
#
# 3. The texts are sorted in descending order of likes, meaning the most liked texts appear at the top, and the least liked among them appears at the bottom.

# %%
# 5. Find and display the text(s) with the maximum reposts. what is its sentiment?
posts = df.groupby('Text')['Retweets'].sum().sort_values(ascending = False).head(10)
plt.figure(figsize = (18,16))
sns.barplot(y= posts.index, x = posts.values, palette = 'Reds')
plt.xticks(fontsize = 35)
plt.yticks(fontsize = 25)
plt.xlabel('Number of Reposts', fontsize = 30)
plt.ylabel('Texts with most number of Reposts', fontsize = 30)
plt.title('Texts with maximum number of Reposts', fontsize = 40)
plt.show()
# Out:
# C:\Users\ABHIJEET CHANDRA\AppData\Local\Temp\ipykernel_99152\1159064792.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y= posts.index, x = posts.values, palette = 'Reds')

# %% [markdown]
# X-axis (Horizontal): "Number of Reposts" – Represents the count of reposts for each text.
#
# Y-axis (Vertical): "Texts with most number of Reposts" – Displays different text entries that have been reposted the most.
#
# Color Scheme: The bars are shaded in different intensities of red (palette='Reds'), where darker shades indicate a higher number of reposts.
#
# # Observations:
#
# 1. The top text has the highest number of reposts, exceeding 70.
#
# 2. The bottom-most text has the least reposts among the displayed entries but still a significant amount.
#
# 3. The bars decrease in size as you move from bottom to top, indicating a ranking order from most to least reposted.

# %%
# 6. Tabulate and Visualize the top 5 countries that have posted the most texts with a positive sentiment.
countries = df[df['Sentiment']=='positive'].groupby('Country')['Sentiment'].count().sort_values(ascending = False).head(5)
print("Top 5 countries that have posted the most texts with a positive sentiment", countries)
plt.figure(figsize = (12,6))
sns.barplot(x = countries.index, y = countries.values, palette = 'Oranges')
plt.xlabel('Countries')
plt.ylabel('Number of texts')
plt.title('Top 5 countries that have posted the most texts with a positive sentiment')
plt.show()
# Out:
# Top 5 countries that have posted the most texts with a positive sentiment Country
# USA          18
# UK           10
# Canada        8
# India         7
# Australia     2
# Name: Sentiment, dtype: int64
# C:\Users\ABHIJEET CHANDRA\AppData\Local\Temp\ipykernel_99152\2958250530.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = countries.index, y = countries.values, palette = 'Oranges')

# %% [markdown]
# Title: "Top 5 countries that have posted the most texts with a positive sentiment"
#
# The chart visualizes the number of texts with a positive sentiment from different countries.
#
# X-axis (Horizontal): "Countries"
#
# Displays the names of the top five countries contributing positive texts.
#
# The listed countries are India, USA (appears twice), UK, and Canada.
#
# Y-axis (Vertical): "Number of texts"
#
# Represents the count of positive sentiment texts posted by each country.
#
# The highest value is 5 texts.
#
# # Observations:
#
# 1. USA leads significantly – The USA has the highest number of texts with a positive sentiment (~18), nearly double that of the second-highest country, the UK (~10).
#
# 2. Gradual decline – The number of texts decreases progressively from the UK (10) → Canada (8) → India (7) → Australia (2).
#
# 3. Australia has the lowest count – Despite being in the top 5, Australia has a much lower number of positive sentiment texts compared to the USA.
#
# 4. Balanced middle group – The UK, Canada, and India show a relatively closer range of values (between 7 to 10 texts), indicating some consistency in their contributions.

# %%
# 7. Find and display all the text(s) with the word ‘Travel’ in their hashtag.
df_travel = df[df['Hashtags'].str.contains('Travel')]
df_travel
# Out:
#       ID                                               Text   Sentiment  \
# 3      3        excited about the upcoming weekend getaway!    positive
# 72    73  excitement building up for the upcoming vacation!  excitement
# 84    85  enjoying every moment of this trip—pure enjoym...   enjoyment
# 145  146  arousal of excitement before a much-awaited trip.     arousal
# 596  597  spontaneously booked a weekend getaway. advent...  excitement
# 610  611  embarked on a road trip to revisit cherished p...         joy
# 622  623  embarked on a solo travel adventure, discoveri...  excitement
#
#             Timestamp               User     Platform  \
# 3    15-01-2023 18:20      AdventureX       Facebook
# 72   18-02-2023 18:45   VacationDreamer     Facebook
# 84   23-02-2023 19:45   TravelExplorer      Facebook
# 145  10-03-2018 09:45   TravelExcitement    Twitter
# 596  05-06-2023 10:00   AdventureSeeker    Instagram
# 610  19-06-2023 16:30    RoadTripSenior     Facebook
# ...

# %%
# 8. Find and display the most popular (most number of likes) posts (top 5) from the year 2020 which were of a negative sentiment.

df_2020_negative_posts = df[(df['Year']==2020) & (df['Sentiment']=='negative')]
df_2020_negative_posts
# Out:
# Empty DataFrame
# Columns: [ID, Text, Sentiment, Timestamp, User, Platform, Hashtags, Retweets, Likes, Country, Year, Month, Day, Hour, Text_length]
# Index: []

# %%
# 9. Find and display a list of Users and their posts whose texts are labeled ‘Happiness’ sentiment.
df_happy = df[df['Sentiment']=='happy']
df_happy
# Out:
#       ID                                               Text Sentiment  \
# 718  719  celebrating a friend's birthday with a surpris...     happy
# 719  720  successfully completing a challenging coding p...     happy
# 720  721  attending a school talent show to support clas...     happy
# 721  722  exploring a new hiking trail with friends over...     happy
# 722  723  winning a friendly sports competition against ...     happy
# 723  724  receiving a heartfelt letter from a pen pal in...     happy
# 724  725  creating a beautiful mural with fellow art ent...     happy
# 725  726  participating in a school-wide art exhibition....     happy
# 726  727  achieving a personal best in a track and field...     happy
# 727  728  collaborating on a science project that receiv...     happy
# 728  729  attending a surprise birthday party organized ...     happy
# 729  730  successfully fundraising for a school charity ...     happy
# ...

# %%
# 10. Tabulate and visualize the years and countrywide tweets of the sentiments. Pick tweets with sentiments, ‘Positive,’ ‘Negative,’ and ‘Neutral’ only.
new_df = df[(df['Sentiment']=='positive') | (df['Sentiment']=='negative') | (df['Sentiment']=='neutral')]
a = new_df.groupby('Country')['Text'].count()
plt.figure(figsize = (12,6))
sns.barplot(x =a.index, y = a.values, palette = 'coolwarm')
plt.ylabel('Number of posts')
plt.title('Number of posts made by each country')


b = new_df.groupby('Year')['Text'].count()
plt.figure(figsize = (12,6))
sns.barplot(x =b.index, y = b.values, palette = 'Blues')
plt.ylabel('Number of posts')
plt.title('Number of posts made in each year')
# Out:
# C:\Users\ABHIJEET CHANDRA\AppData\Local\Temp\ipykernel_99152\132560787.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x =a.index, y = a.values, palette = 'coolwarm')
# C:\Users\ABHIJEET CHANDRA\AppData\Local\Temp\ipykernel_99152\132560787.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x =b.index, y = b.values, palette = 'Blues')
# Text(0.5, 1.0, 'Number of posts made in each year')

# %% [markdown]
# 1. Country-wise post distribution (Top Chart)
#
# The USA has the highest number of posts (~27), making it the most active country.
#
# Canada and the UK have similar post counts (~14-15).
#
# India (~8 posts) is lower compared to Canada and the UK.
#
# Australia has the least posts (~4), indicating lower participation.
#
# 2. Year-wise post distribution (Bottom Chart)
#
# All posts appear to be from 2023, with ~67 posts recorded.
#
# No other years are represented in this dataset.
